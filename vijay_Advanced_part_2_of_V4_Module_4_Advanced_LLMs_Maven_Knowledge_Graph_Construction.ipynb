# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaypoluri/AI/blob/main/vijay_Advanced_part_2_of_V4_Module_4_Advanced_LLMs_Maven_Knowledge_Graph_Construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# In the [basic notebook for Module 5](https://colab.research.google.com/drive/1OX3I6GKBlfcJGyecyK8VNWbY5l4MA2dA?usp=sharing) of [Enterprise RAG and Multi-Agent Applications](https://maven.com/boring-bot/advanced-llm), we explored the fundamentals of knowledge graph construction and Graph RAG. We built a hotel reviews knowledge graph, migrated it to Neo4j, and implemented a template-based retriever for answering natural language queries about our graph data.
#
# This advanced notebook builds on those foundations to explore more sophisticated Graph RAG techniques and hybrid approaches. While our basic notebook focused on core concepts and implementation, this notebook delves into methods that significantly enhance both the graph itself and our retrieval capabilities - including the pattern most frequently discussed in modern Graph RAG demonstrations, the LLM-driven extraction of structured triplets from unstructured text.

# %% [markdown]
# ## Architecture Overview
# Our final graph RAG system will have several key components:
#
# ![architecture (1).svg](data:image/svg+xml;base64,...)
#
# The key enhancements we'll cover in this notebook include:
#
# 1. **Graph Enrichment**: Using LLMs to extract entities and relationships from unstructured text fields, expanding our knowledge graph beyond the structured data
#
# 2. **Vector Indexing**: Adding semantic search capabilities to our graph nodes, enabling similarity-based retrieval alongside structural queries
#
# 3. **Advanced Retrieval**: Implementing and comparing Text2Cypher, template-based, and vector retrieval
#
# 4. **Performance Analysis**: Systematically comparing different RAG strategies to understand when graph-based approaches outperform traditional vector RAG

# %% [markdown]
# ## Prerequisites
#
# * Completion of the basic Knowledge Graph RAG notebook
# * Access to the same Neo4j database used in the basic notebook
# * OpenAI API key

# %% [markdown]
# # Setup
#
# Let's begin by setting up our connections and exploring how to enhance our knowledge graph with entities extracted from unstructured text.
#
# We will use the same Neo4j database instance that ingested our data in the basic notebook. Make sure that you have entered your NEO4J_URI and NEO4J_PASSWORD key-value pairs into your Colab Secrets before continuing.

# %%
# %pip install pyvis IPython cchardet datasets langchain==0.1.17 neo4j openai tiktoken langchain-community langchain-experimental json-repair

from getpass import getpass
import os
from google.colab import userdata
import json
import pandas as pd
from typing import Optional, List, Dict, Any
from openai import OpenAI
from neo4j import GraphDatabase
from dataclasses import dataclass

# Configure OpenAI API key
if os.getenv("OPENAI_API_KEY") is None:
  try:
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
  except (userdata.TimeoutException, userdata.SecretNotFoundError):
    if any(['VSCODE' in x for x in os.environ.keys()]):
      print('Please enter password in the VS Code prompt at the top of your VS Code window!')
    os.environ["OPENAI_API_KEY"] = getpass("")

assert os.getenv("OPENAI_API_KEY", "").startswith("sk-"), "This doesn't look like a valid OpenAI API key"
print("OpenAI API key configured")

# Connect to Neo4j
url = userdata.get('NEO4J_URI')
username = "neo4j"
password = userdata.get('NEO4J_PASSWORD')
password = "q33sNW6OPpuEF_V8gdMtA2jQbbjX4AITIhs-25El1P0"


driver = GraphDatabase.driver(url, auth=(username, password))
print("Connected to Neo4j database")

# Initialize OpenAI client
openai_client = OpenAI()
# Out:
# Requirement already satisfied: pyvis in /usr/local/lib/python3.11/dist-packages (0.3.2)
# Requirement already satisfied: IPython in /usr/local/lib/python3.11/dist-packages (7.34.0)
# Requirement already satisfied: cchardet in /usr/local/lib/python3.11/dist-packages (2.1.7)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: langchain==0.1.17 in /usr/local/lib/python3.11/dist-packages (0.1.17)
# Requirement already satisfied: neo4j in /usr/local/lib/python3.11/dist-packages (5.28.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.61.1)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.0.38)
# Requirement already satisfied: langchain-experimental in /usr/local/lib/python3.11/dist-packages (0.0.58)
# Requirement already satisfied: json-repair in /usr/local/lib/python3.11/dist-packages (0.39.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (3.11.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (1.33)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (0.1.53)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain==0.1.17) (8.5.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis) (4.0.2)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from IPython) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from IPython) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from IPython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from IPython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from IPython) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from IPython) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython) (4.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9.6->pyvis) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->langchain==0.1.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->langchain==0.1.17) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.1.17) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.1.17) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.0.0)
# OpenAI API key configured
# Connected to Neo4j database

# %% [markdown]
# # Expanding the graph from unstructured text fields with LLMs and pre-defined schema types

# %% [markdown]
# Graph RAG really shines when you have large amounts of unstructured text data which contain many and complex relationships. In fact, most publicly available examples and demos you see for Graph RAG involve unstructured text as the primary data sources. In our case, with the structured dataset of hotel reviews, we can turn to the hotel descriptions for such data. Let's now look at how to build a pipeline for entity and relationship extraction from unstructured text.

# %%
from typing import Optional, List, Dict, Any
from openai import OpenAI
import pandas as pd
import json

class Neo4jGraphExtractor:
    def __init__(self, openai_client: OpenAI, neo4j_driver: GraphDatabase, entity_types: List[str], rel_types: List[str], instruct_notes: List[str] = None, temperature: float = 0 ):
        self.client = openai_client
        self.temperature = temperature
        self.driver = driver
        self.entity_types = entity_types
        self.rel_types = rel_types
        self.instruct_notes = instruct_notes

    def _create_prompt(self, hotel_name: str, text: str) -> str:
        return f"""
-Goal-
Given a text document that contains the description of a specific hotel and a list of entity types, identify all entities of those types from the text and all relationships among the identified entities.

-Steps-
1. Identify all entities. There is a known root entity, which is the described hotel. For each identified entity, extract the following information:
- entity_name: Name of the entity, capitalized
- entity_type: One of the following types: [{self.entity_types}]
- entity_description: Comprehensive description of the entity's attributes and activities

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are clearly related to each other.

For each pair of related entities, extract:
- source_entity: name of the source entity
- target_entity: name of the target entity
- relationship_type: One of the following types: {self.rel_types}

3. Return output as a single JSON list containing all entities and relationships.

-Real Data-
######################
Root hotel: {hotel_name}
text: {text}
######################
output:
"""

    def _parse_llm_response(self, response: str) -> Dict[str, List[Dict[str, Any]]]:
      try:
          # Clean up markdown formatting if present
          if response.startswith('```'):
              # Extract content between code blocks
              response = response.split('```')[1]
              # Remove json language identifier if present
              if response.startswith('json'):
                  response = response[4:]
              response = response.strip()

          # Parse JSON
          try:
              data = json.loads(response)

              # Handle both direct entity/relationship format and nested format
              if isinstance(data, dict) and 'entities' in data and 'relationships' in data:
                  return {
                      "entities": data['entities'],
                      "relationships": data['relationships']
                  }
              if isinstance(data, list) and len(data) > 0:
                  # Original format handling
                  entities = [item for item in data if "type" in item]
                  relationships = [item for item in data if "relationship" in item]
                  return {
                      "entities": entities,
                      "relationships": relationships
                  }
              # Fallback if data is not in any expected shape
              return {"entities": [], "relationships": []}

          except json.JSONDecodeError as e:
              # If standard format fails, try the alternative format
              print(f"JSONDecodeError thrown in inner block: {str(e)}")
              if str(e).startswith("Extra data"):
                try:
                  # Assuming the format is [entities_list, relationships_list]
                  wrapped = f"[{response}]"
                  arr = json.loads(wrapped)
                  if len(arr) == 2:
                    entities_list, relationships_list = arr
                    return {
                        "entities": entities_list,
                        "relationships": relationships_list
                    }
                except json.JSONDecodeError:
                  raise e
              else:
                  # If neither format works, raise the original error
                  raise e
      except json.JSONDecodeError as e:
          print(f"Error parsing JSON response: {str(e)}")
          print("Response was:", response)
          return {"entities": [], "relationships": []}

    def process_text(self, hotel_name: str, text: str) -> Dict[str, List[Dict[str, Any]]]:
        """
        Process a hotel description text and extract entities and relationships.

        Args:
            hotel_name: Name of the hotel (root entity)
            text: Hotel description text to process

        Returns:
            Dictionary containing lists of extracted entities and relationships
        """
        prompt = self._create_prompt(hotel_name, text)

        response = self.client.chat.completions.create(
            model="gpt-4o",  # or your preferred model
            temperature=self.temperature,
            messages=[
                {"role": "system", "content": "You are a helpful assistant that extracts entities and relationships from text and returns them in JSON format."},
                {"role": "user", "content": prompt}
            ],
            response_format={"type": "json_object"}
        )

        # Extract the content from the response
        result = response.choices[0].message.content

        # Parse and return the structured data
        return self._parse_llm_response(result)

    def process_and_save(self, hotel_name: str, text: str) -> Dict[str, List[Dict[str, Any]]]:
        """
        Process hotel description text, extract entities and relationships, and save to Neo4j.

        Args:
            hotel_name: Name of the hotel (root entity)
            text: Hotel description text to process

        Returns:
            Dictionary containing lists of extracted entities and relationships
        """
        try:
            result = self.process_text(hotel_name, text)

            if result == {"entities": [], "relationships": []}:
                print(f"No entities or relationships found for {hotel_name}, skipping upload")
                return result
            print(f"Processing and saving result {result}")

            # Save to Neo4j within a single session
            with self.driver.session() as session:
                # Add entities
                for entity in result['entities']:
                    cypher_query = """
                    MERGE (n:__Entity__ {name: $name})
                    SET n.entity = $type,
                        n.description = $description
                    WITH n
                    CALL apoc.create.addLabels(n, [$type]) YIELD node
                    RETURN distinct 'done' AS result
                    """
                    session.run(
                        cypher_query,
                        name=entity['entity_name'],
                        type=entity['entity_type'].upper(),
                        description=entity['entity_description']
                    )

                # Add relationships
                for rel in result['relationships']:
                    # Format the relationship type directly into the query
                    cypher_query = f"""
                    MATCH (a:__Entity__), (b:__Entity__)
                    WHERE a.name = $source AND b.name = $target
                    MERGE (a)-[r:{rel['relationship_type']}]->(b)
                    RETURN distinct 'done' AS result
                    """
                    session.run(
                        cypher_query,
                        source=rel['source_entity'],
                        target=rel['target_entity']
                    )

            return result

        except Exception as e:
            print(f"Error processing hotel {hotel_name}: {str(e)}")
            return {"entities": [], "relationships": []}


    def process_from_dataframe(self,
                             dataset: pd.DataFrame,
                             name_column: str,
                             description_column: str,
                             batch_size: Optional[int] = None):
        """Process hotels from pandas DataFrame"""
        total = len(dataset)
        for idx, row in dataset.iterrows():
            print(f"Processing hotel {idx + 1}/{total}: {row[name_column]}")
            self.process_and_save(
                hotel_name=row[name_column],
                text=row[description_column]
            )

            if batch_size and (idx + 1) % batch_size == 0:
                print(f"Completed batch of {batch_size} hotels")

    def process_from_neo4j(self, batch_size: Optional[int] = None):
        """Process hotels from existing Neo4j HOTEL nodes"""
        with self.driver.session() as session:
            # First, count total hotels
            count_query = """
            MATCH (h:HOTEL)
            RETURN count(h) as total
            """
            total = session.run(count_query).single()['total']

            # Then process in batches if specified
            query = """
            MATCH (h:HOTEL)
            RETURN h.name as name, h.description as description
            """
            if batch_size:
                query += f" SKIP $skip LIMIT {batch_size}"

            processed = 0
            while processed < total:
                results = session.run(query, skip=processed)
                for record in results:
                    processed += 1
                    if record['description'] is None:
                        print(f"Skipping hotel {processed}/{total}: {record['name']} (no description)")
                        continue
                    print(f"Processing hotel {processed}/{total}: {record['name']}")
                    self.process_and_save(
                        hotel_name=record['name'],
                        text=record['description']
                    )

                if batch_size:
                    print(f"Completed batch of {batch_size} hotels")

    def process_hotels(self,
                      source: str = 'neo4j',
                      dataset: Optional[pd.DataFrame] = None,
                      name_column: Optional[str] = None,
                      description_column: Optional[str] = None,
                      batch_size: Optional[int] = None):
        """
        Unified interface for processing hotels from either source

        Args:
            source: Either 'neo4j' or 'dataframe'
            dataset: Required if source is 'dataframe'
            name_column: Required if source is 'dataframe'
            description_column: Required if source is 'dataframe'
            batch_size: Optional batch size for processing
        """
        if source == 'neo4j':
            self.process_from_neo4j(batch_size=batch_size)
        elif source == 'dataframe':
            if not all([dataset is not None,
                       name_column is not None,
                       description_column is not None]):
                raise ValueError("Dataset and column names required for DataFrame source")
            self.process_from_dataframe(
                dataset=dataset,
                name_column=name_column,
                description_column=description_column,
                batch_size=batch_size
            )
        else:
            raise ValueError("Source must be either 'neo4j' or 'dataframe'")

# %%
openai_client = OpenAI()
extractor = Neo4jGraphExtractor(openai_client=openai_client,
                                neo4j_driver=driver,
                                entity_types = ["HOTEL", "AMENITY", "TOURIST_ATTRACTION"],
                                rel_types=["HAS_AMENITY", "LOCATED_NEARBY"],
                                )

# Process from Neo4j:
extractor.process_hotels(source='neo4j', batch_size=100)
# Out:
# Skipping hotel 1/149: Royal National Hotel (no description)
# Processing hotel 2/149: Grant Plaza Hotel
# Processing and saving result {'entities': [{'entity_name': 'Grant Plaza Hotel', 'entity_type': 'HOTEL', 'entity_description': "Grant Plaza Hotel is a limited service boutique hotel located in the heart of the city. It is recommended by many travellers as one of the best valued hotels in San Francisco. The hotel is conveniently located at the gateway to Chinatown, 3 blocks from Union Square, and within easy walking distance to many fine restaurants and theaters in this exciting city. It is also only 1 block to the famous San Francisco Cable Car line, the Bank of American Building in the Financial District and the 5 stars Ritz Carlton Hotel in Nob Hill. It caters to both business and pleasure travelers, and is the perfect place for a vacation getaway. The Hotel has just a completed renovation in 2015. The comfortable guestrooms are appointed with contemporary furnishings, and have recently been renovated for guest convenience with hairdryer, electronic keycard lock and free (WiFi) high speed internet access. The professional and attentive staff at the hotel will ensure that all guests are well taken care of. If you're seeking comfort and affordability all in one, this is one of the best value hotels in San Francisco."}, {'entity_name': 'Chinatown', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The gateway to Chinatown is located near Grant Plaza Hotel.'}, {'entity_name': 'Union Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Union Square is located 3 blocks from Grant Plaza Hotel.'}, {'entity_name': 'San Francisco Cable Car', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The famous San Francisco Cable Car line is located 1 block from Grant Plaza Hotel.'}, {'entity_name': 'Bank of American Building', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The Bank of American Building is located in the Financial District, 1 block from Grant Plaza Hotel.'}, {'entity_name': 'Ritz Carlton Hotel', 'entity_type': 'HOTEL', 'entity_description': 'The 5 stars Ritz Carlton Hotel is located in Nob Hill, 1 block from Grant Plaza Hotel.'}, {'entity_name': 'WiFi', 'entity_type': 'AMENITY', 'entity_description': 'Free high speed internet access available at Grant Plaza Hotel.'}, {'entity_name': 'Hairdryer', 'entity_type': 'AMENITY', 'entity_description': 'Hairdryer available in guestrooms at Grant Plaza Hotel.'}, {'entity_name': 'Electronic Keycard Lock', 'entity_type': 'AMENITY', 'entity_description': 'Electronic keycard lock available in guestrooms at Grant Plaza Hotel.'}], 'relationships': [{'source_entity': 'Grant Plaza Hotel', 'target_entity': 'Chinatown', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'Union Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'San Francisco Cable Car', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'Bank of American Building', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'Ritz Carlton Hotel', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'WiFi', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'Hairdryer', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Grant Plaza Hotel', 'target_entity': 'Electronic Keycard Lock', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 3/149: The Empire Hotel
# Processing and saving result {'entities': [{'entity_name': 'The Empire Hotel', 'entity_type': 'HOTEL', 'entity_description': 'A boutique NYC hotel providing luxury accommodations overlooking Broadway / Columbus Avenue, with 427 Deluxe guest rooms and suites, WiFi, Pool Deck open seasonally, PJ Clarke’s Restaurant, Rooftop Lounge, Lobby Lounge. Featured in Gossip Girl.'}, {'entity_name': 'Central Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A legendary New York City landmark, known for its vast green spaces and recreational areas.'}, {'entity_name': 'Lincoln Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A legendary New York City landmark, known for its cultural and performing arts venues.'}, {'entity_name': 'WiFi', 'entity_type': 'AMENITY', 'entity_description': 'Wireless internet access available throughout the hotel.'}, {'entity_name': 'Pool Deck', 'entity_type': 'AMENITY', 'entity_description': 'A seasonal outdoor pool area available to guests.'}, {'entity_name': 'PJ Clarke’s Restaurant', 'entity_type': 'AMENITY', 'entity_description': 'A dining establishment located within the hotel.'}, {'entity_name': 'Rooftop Lounge', 'entity_type': 'AMENITY', 'entity_description': 'A lounge area located on the rooftop of the hotel, offering views and cocktails.'}, {'entity_name': 'Lobby Lounge', 'entity_type': 'AMENITY', 'entity_description': 'A lounge area located in the lobby of the hotel, known for serving the Chuck Bass cocktail.'}], 'relationships': [{'source_entity': 'The Empire Hotel', 'target_entity': 'Central Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Empire Hotel', 'target_entity': 'Lincoln Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Empire Hotel', 'target_entity': 'WiFi', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'The Empire Hotel', 'target_entity': 'Pool Deck', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'The Empire Hotel', 'target_entity': 'PJ Clarke’s Restaurant', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'The Empire Hotel', 'target_entity': 'Rooftop Lounge', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'The Empire Hotel', 'target_entity': 'Lobby Lounge', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 4/149: Hyatt Grand Central New York
# Processing and saving result {'entities': [{'entity_name': 'Hyatt Grand Central New York', 'entity_type': 'HOTEL', 'entity_description': 'Located in the heart of midtown Manhattan, the only hotel connected to the majesty and advantages of Grand Central Terminal. Offers a to-go market, 24-hour fitness center, and complimentary Wi-Fi.'}, {'entity_name': 'Grand Central Terminal', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major transit hub and architectural landmark in New York City, connected to the Hyatt Grand Central New York.'}, {'entity_name': 'Chrysler Building', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An iconic Art Deco skyscraper located in midtown Manhattan, near the Hyatt Grand Central New York.'}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major commercial intersection and entertainment center in New York City, near the Hyatt Grand Central New York.'}, {'entity_name': '5th Avenue', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major thoroughfare in Manhattan known for its prestigious shopping, near the Hyatt Grand Central New York.'}, {'entity_name': 'Empire State Building', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A famous skyscraper and landmark in New York City, near the Hyatt Grand Central New York.'}, {'entity_name': 'Central Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A large public park in New York City, near the Hyatt Grand Central New York.'}, {'entity_name': 'Rockefeller Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A large complex consisting of 19 commercial buildings in New York City, near the Hyatt Grand Central New York.'}, {'entity_name': 'Theatre District', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An area in New York City known for its concentration of theaters, near the Hyatt Grand Central New York.'}, {'entity_name': 'To-go Market', 'entity_type': 'AMENITY', 'entity_description': 'A market offering quick and convenient food options, available at the Hyatt Grand Central New York.'}, {'entity_name': '24-hour Fitness Center', 'entity_type': 'AMENITY', 'entity_description': 'A fitness center open 24 hours, available at the Hyatt Grand Central New York.'}, {'entity_name': 'Complimentary Wi-Fi', 'entity_type': 'AMENITY', 'entity_description': 'Free wireless internet access, available at the Hyatt Grand Central New York.'}], 'relationships': [{'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Grand Central Terminal', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Chrysler Building', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': '5th Avenue', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Empire State Building', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Central Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Rockefeller Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Theatre District', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'To-go Market', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': '24-hour Fitness Center', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hyatt Grand Central New York', 'target_entity': 'Complimentary Wi-Fi', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 5/149: Paramount Hotel Times Square
# Processing and saving result {'entities': [{'entity_name': 'Paramount Hotel Times Square', 'entity_type': 'HOTEL', 'entity_description': "The bustle of the street disappears as you step inside Paramount Hotel. Our Times Square, New York hotel's chic, two-story lobby, with its reflective fireplace, dramatic lighting, and rich textures, sets the stage for a hip, indulgent experience. Whether you are traveling for business or pleasure, Paramount Hotel makes a stylish, comfortable, and centrally located home base for all of your adventures in New York City. Recently updated but retaining its historical charm, Paramount Hotel is the only hotel near Broadway NYC with genuine personality."}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major commercial intersection, tourist destination, entertainment center, and neighborhood in Midtown Manhattan, New York City.'}, {'entity_name': 'Broadway NYC', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A famous street in New York City known for its theaters and the heart of the American theater industry.'}, {'entity_name': 'Reflective Fireplace', 'entity_type': 'AMENITY', 'entity_description': "A feature of the hotel's chic, two-story lobby, contributing to the dramatic lighting and rich textures."}, {'entity_name': 'Dramatic Lighting', 'entity_type': 'AMENITY', 'entity_description': "Part of the hotel's lobby design, enhancing the chic and indulgent experience."}, {'entity_name': 'Rich Textures', 'entity_type': 'AMENITY', 'entity_description': "A design element in the hotel's lobby, adding to the overall chic and indulgent atmosphere."}], 'relationships': [{'source_entity': 'Paramount Hotel Times Square', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Paramount Hotel Times Square', 'target_entity': 'Broadway NYC', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Paramount Hotel Times Square', 'target_entity': 'Reflective Fireplace', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Paramount Hotel Times Square', 'target_entity': 'Dramatic Lighting', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Paramount Hotel Times Square', 'target_entity': 'Rich Textures', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 6/149: The Manhattan at Times Square Hotel
# Processing and saving result {'entities': [{'entity_name': 'The Manhattan at Times Square Hotel', 'entity_type': 'HOTEL', 'entity_description': "The Manhattan at Times Square Hotel effortlessly merges the 24/7 excitement of Times Square with the age-old glamour of New York. Delighting guests with its prime location and classic Art Deco detailing, this landmark hotel was built in 1962 during New York City's heady Mad Men era, its commanding Seventh Avenue location a testament to both longevity and lavish attention to detail."}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Times Square is known for its 24/7 excitement and is a major commercial and tourist hub in New York City.'}, {'entity_name': 'New York', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'New York is a major city known for its glamour and historical significance, including the Art Deco era.'}, {'entity_name': 'Seventh Avenue', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Seventh Avenue is a major thoroughfare in New York City, known for its significant locations and historical importance.'}], 'relationships': [{'source_entity': 'The Manhattan at Times Square Hotel', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Manhattan at Times Square Hotel', 'target_entity': 'New York', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Manhattan at Times Square Hotel', 'target_entity': 'Seventh Avenue', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 7/149: Stanyan Park Hotel
# Processing and saving result {'entities': [{'entity_name': 'Stanyan Park Hotel', 'entity_type': 'HOTEL', 'entity_description': 'Elegantly restored in 1983, The Stanyan Park Hotel, listed on the National Register of Historic Places, is an affordable, turn of the century award-winning hotel with comfort, design and hospitality that will transport you back to a bygone era of style and grace.'}, {'entity_name': 'Golden Gate Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': "San Francisco's famous park, filled with gardens, museums, art, flowers, trees, lakes, wildlife and birds, ideal for a romantic evening stroll or an early morning jog."}, {'entity_name': 'Haight & Ashbury', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Historic street known for its cultural significance, located steps away from the hotel.'}, {'entity_name': 'USF', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'World renowned university located about half-mile away from the hotel.'}, {'entity_name': 'UCSF', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'World renowned university located about half-mile away from the hotel.'}, {'entity_name': 'Paid self parking lot', 'entity_type': 'AMENITY', 'entity_description': 'Parking facility available for guests.'}, {'entity_name': 'Free Wi-Fi', 'entity_type': 'AMENITY', 'entity_description': 'Complimentary wireless internet access for guests.'}, {'entity_name': "Complimentary Manager's wine and cheese hour", 'entity_type': 'AMENITY', 'entity_description': 'Free wine and cheese service available on weekdays.'}, {'entity_name': 'Light Tea service', 'entity_type': 'AMENITY', 'entity_description': 'Evening tea service available daily.'}, {'entity_name': 'Expanded continental breakfast', 'entity_type': 'AMENITY', 'entity_description': 'Daily healthy and delicious breakfast included.'}], 'relationships': [{'source_entity': 'Stanyan Park Hotel', 'target_entity': 'Golden Gate Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'Haight & Ashbury', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'USF', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'UCSF', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'Paid self parking lot', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'Free Wi-Fi', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': "Complimentary Manager's wine and cheese hour", 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'Light Tea service', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Stanyan Park Hotel', 'target_entity': 'Expanded continental breakfast', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 8/149: YOTEL Istanbul Airport Hotel (Landside)
# Processing and saving result {'entities': [{'entity_name': 'YOTEL Istanbul Airport Hotel (Landside)', 'entity_type': 'HOTEL', 'entity_description': "Located on the 'landside' of Istanbul Airport's main terminal building, offering 171 modern cabins, a gym, flexible meeting rooms, and a stylish bar and restaurant."}, {'entity_name': 'Gym', 'entity_type': 'AMENITY', 'entity_description': 'A facility available at YOTEL Istanbul Airport Hotel (Landside).'}, {'entity_name': 'Flexible Meeting Rooms', 'entity_type': 'AMENITY', 'entity_description': 'Meeting rooms available at YOTEL Istanbul Airport Hotel (Landside).'}, {'entity_name': 'Stylish Bar and Restaurant', 'entity_type': 'AMENITY', 'entity_description': 'A bar and restaurant available at YOTEL Istanbul Airport Hotel (Landside).'}, {'entity_name': 'Istanbul Airport', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The location where YOTEL Istanbul Airport Hotel (Landside) is situated, with a main terminal building.'}], 'relationships': [{'source_entity': 'YOTEL Istanbul Airport Hotel (Landside)', 'target_entity': 'Gym', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'YOTEL Istanbul Airport Hotel (Landside)', 'target_entity': 'Flexible Meeting Rooms', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'YOTEL Istanbul Airport Hotel (Landside)', 'target_entity': 'Stylish Bar and Restaurant', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'YOTEL Istanbul Airport Hotel (Landside)', 'target_entity': 'Istanbul Airport', 'relationship_type': 'LOCATED_NEARBY'}]}
# Skipping hotel 9/149: Palmers Lodge Swiss Cottage (no description)
# Processing hotel 10/149: St. Athans Hotel
# Processing and saving result {'entities': [{'entity_name': 'St. Athans Hotel', 'entity_type': 'HOTEL', 'entity_description': 'The St. Athans Hotel, Bloomsbury, is a simple, eco-friendly, family-run bed & breakfast in the heart of London. It’s grade II listed 200 year old Georgian terraced houses retain many of its their original features, fitting in well with the historic area.'}, {'entity_name': 'British Museum', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major museum located within walking distance of the St. Athans Hotel.'}, {'entity_name': 'University of London', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major educational institution located within walking distance of the St. Athans Hotel.'}, {'entity_name': 'Covent Garden', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A popular shopping and entertainment area located within walking distance of the St. Athans Hotel.'}, {'entity_name': 'British Library', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major library located within walking distance of the St. Athans Hotel.'}, {'entity_name': 'Madame Tussaud’s', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A famous wax museum located a short bus ride away from the St. Athans Hotel.'}, {'entity_name': 'London’s West End', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An area known for its many shops, theatres, bars, and restaurants, located a short bus ride away from the St. Athans Hotel.'}], 'relationships': [{'source_entity': 'St. Athans Hotel', 'target_entity': 'British Museum', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'St. Athans Hotel', 'target_entity': 'University of London', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'St. Athans Hotel', 'target_entity': 'Covent Garden', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'St. Athans Hotel', 'target_entity': 'British Library', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'St. Athans Hotel', 'target_entity': 'Madame Tussaud’s', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'St. Athans Hotel', 'target_entity': 'London’s West End', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 11/149: Strand Palace
# Processing and saving result {'entities': [{'entity_name': 'Strand Palace', 'entity_type': 'HOTEL', 'entity_description': 'Strand Palace is surrounded by the best London has to offer. Set in the heart of London, the hotel is mere moments from Covent Garden, Trafalgar Square and the Thames, making it the perfect location for discovering cultural icons and for those travelling on business. The hotel is home to 788 bedrooms and offers a guest service centre and gym for guest use. For in house dining, guests can visit Haxells Restaurant & Bar, the perfect place to enjoy great food, cocktails and more in the heart of London.'}, {'entity_name': 'Covent Garden', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Covent Garden is a cultural icon located near Strand Palace.'}, {'entity_name': 'Trafalgar Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Trafalgar Square is a cultural icon located near Strand Palace.'}, {'entity_name': 'Thames', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The Thames is a cultural icon located near Strand Palace.'}, {'entity_name': 'Haxells Restaurant & Bar', 'entity_type': 'AMENITY', 'entity_description': 'Haxells Restaurant & Bar is the perfect place to enjoy great food, cocktails and more in the heart of London. Guests can enjoy modern British cuisine with modern art deco decor throughout the restaurant, bar, afternoon tearoom and private dining room.'}, {'entity_name': 'Guest Service Centre', 'entity_type': 'AMENITY', 'entity_description': 'The hotel offers a guest service centre for guest use.'}, {'entity_name': 'Gym', 'entity_type': 'AMENITY', 'entity_description': 'The hotel offers a gym for guest use.'}], 'relationships': [{'source_entity': 'Strand Palace', 'target_entity': 'Covent Garden', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Strand Palace', 'target_entity': 'Trafalgar Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Strand Palace', 'target_entity': 'Thames', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Strand Palace', 'target_entity': 'Haxells Restaurant & Bar', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Strand Palace', 'target_entity': 'Guest Service Centre', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Strand Palace', 'target_entity': 'Gym', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 12/149: The Tower Hotel
# Processing and saving result {'entities': [{'entity_name': 'The Tower Hotel', 'entity_type': 'HOTEL', 'entity_description': 'The Tower Hotel is nestled between the River Thames, St Katharine Docks and alongside the World Heritage Site, the Tower of London, boasting unparalleled views of the iconic Tower Bridge.'}, {'entity_name': 'River Thames', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major river flowing through southern England, including London.'}, {'entity_name': 'St Katharine Docks', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A marina and residential area in central London, close to the Tower of London.'}, {'entity_name': 'Tower of London', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A historic castle located on the north bank of the River Thames in central London.'}, {'entity_name': 'Tower Bridge', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An iconic symbol of London, a combined bascule and suspension bridge in London.'}], 'relationships': [{'source_entity': 'The Tower Hotel', 'target_entity': 'River Thames', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Tower Hotel', 'target_entity': 'St Katharine Docks', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Tower Hotel', 'target_entity': 'Tower of London', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'The Tower Hotel', 'target_entity': 'Tower Bridge', 'relationship_type': 'LOCATED_NEARBY'}]}
# Skipping hotel 13/149: Travelodge London Central City Road (no description)
# Processing hotel 14/149: Travelodge London Covent Garden
# Processing and saving result {'entities': [{'entity_name': 'Travelodge London Covent Garden', 'entity_type': 'HOTEL', 'entity_description': 'An amazing hotel with multilingual staff located in the heart of the theatre land in the west end of London.'}, {'entity_name': 'Multilingual Staff', 'entity_type': 'AMENITY', 'entity_description': 'Staff at the hotel who can speak multiple languages.'}, {'entity_name': 'Theatre Land', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A popular area in the west end of London known for its theatres.'}, {'entity_name': 'West End', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A famous area in London known for entertainment and cultural attractions.'}], 'relationships': [{'source_entity': 'Travelodge London Covent Garden', 'target_entity': 'Multilingual Staff', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Travelodge London Covent Garden', 'target_entity': 'Theatre Land', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Travelodge London Covent Garden', 'target_entity': 'West End', 'relationship_type': 'LOCATED_NEARBY'}]}
# Skipping hotel 15/149: Travelodge London Excel (no description)
# Processing hotel 16/149: Travelodge London Kings Cross Royal Scot
# Processing and saving result {'entities': [{'entity_name': 'Travelodge London Kings Cross Royal Scot', 'entity_type': 'HOTEL', 'entity_description': "Six-story Hotel overlooking Percy Circus, 1/4 mile from King's Cross Station."}, {'entity_name': 'Percy Circus', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A location that the hotel overlooks.'}, {'entity_name': "King's Cross Station", 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major railway station located 1/4 mile from the hotel.'}], 'relationships': [{'source_entity': 'Travelodge London Kings Cross Royal Scot', 'target_entity': 'Percy Circus', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Travelodge London Kings Cross Royal Scot', 'target_entity': "King's Cross Station", 'relationship_type': 'LOCATED_NEARBY'}]}
# Skipping hotel 17/149: Travelodge London Docklands Central (no description)
# Processing hotel 18/149: Crowne Plaza Times Square Manhattan, an IHG Hotel
# Processing and saving result {'entities': [{'entity_name': 'Crowne Plaza Times Square Manhattan', 'entity_type': 'HOTEL', 'entity_description': "Nestled in the heart of Midtown, our hotel puts you directly on Broadway between 48th and 49th Streets at the doorstep of Times Square. Stay steps from the greatest musical theater in the world, surrounded by iconic New York landmarks, top Fortune 500 companies, and the city's best shopping. Perfecting the art of blended travel, our hotel puts you blocks from Central Park, Rockefeller Center, and Radio City Music Hall. When you're not exploring or heading to a meeting, unwind in spacious rooms with all the essentials, including workspaces. Relax, take in the city, and leave the details to us."}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The doorstep of Times Square, surrounded by iconic New York landmarks and the greatest musical theater in the world.'}, {'entity_name': 'Central Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Blocks from the hotel, a famous urban park in New York City.'}, {'entity_name': 'Rockefeller Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Blocks from the hotel, a large complex consisting of 19 commercial buildings.'}, {'entity_name': 'Radio City Music Hall', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Blocks from the hotel, an entertainment venue located in Rockefeller Center.'}, {'entity_name': 'Workspaces', 'entity_type': 'AMENITY', 'entity_description': 'Spacious rooms with all the essentials, including workspaces.'}], 'relationships': [{'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Central Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Rockefeller Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Radio City Music Hall', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Workspaces', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 19/149: Pod 51 Hotel
# Processing and saving result {'entities': [{'entity_name': 'Pod 51 Hotel', 'entity_type': 'HOTEL', 'entity_description': 'Pod 51 is the most affordable hotel in NYC, with a focus on style and comfort. We offer room types for every budget and preference. Free weekday walking tours and WiFi. Kick back and relax in our lobby, grab a bite to eat at our cafe, or soak up the city in our beautiful rooftop garden.'}, {'entity_name': 'Walking Tours', 'entity_type': 'AMENITY', 'entity_description': 'Free weekday walking tours offered by the hotel.'}, {'entity_name': 'WiFi', 'entity_type': 'AMENITY', 'entity_description': 'Free WiFi available at the hotel.'}, {'entity_name': 'Lobby', 'entity_type': 'AMENITY', 'entity_description': 'A place to kick back and relax within the hotel.'}, {'entity_name': 'Cafe', 'entity_type': 'AMENITY', 'entity_description': 'A place to grab a bite to eat within the hotel.'}, {'entity_name': 'Rooftop Garden', 'entity_type': 'AMENITY', 'entity_description': 'A beautiful rooftop garden to soak up the city.'}], 'relationships': [{'source_entity': 'Pod 51 Hotel', 'target_entity': 'Walking Tours', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Pod 51 Hotel', 'target_entity': 'WiFi', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Pod 51 Hotel', 'target_entity': 'Lobby', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Pod 51 Hotel', 'target_entity': 'Cafe', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Pod 51 Hotel', 'target_entity': 'Rooftop Garden', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 20/149: Hotel Edison
# Processing and saving result {'entities': [{'entity_name': 'Hotel Edison', 'entity_type': 'HOTEL', 'entity_description': 'Hotel Edison has been a staple of Times Square since its opening in 1931, when Thomas Edison turned on the lights of the hotel himself. The historic hotel is among the first Art Deco hotels in New York City’s Theater District and has become synonymous with celebrity, art, and excitement over the past eight decades. Hotel Edison’s vibrant energy, spacious accommodations, and notable restaurants and jazz bar provide guests with a one-of-a-kind refuge in the heart of Times Square.'}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major commercial intersection, tourist destination, entertainment center, and neighborhood in Midtown Manhattan, New York City.'}, {'entity_name': 'Time Warner Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A mixed-use building complex in Columbus Circle, Manhattan, New York City.'}, {'entity_name': 'Rockefeller Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A large complex consisting of 19 commercial buildings covering 22 acres between 48th Street and 51st Street in New York City.'}, {'entity_name': 'MoMA', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The Museum of Modern Art, an art museum located in Midtown Manhattan in New York City.'}, {'entity_name': 'Fifth Avenue Shops', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'World-renowned shopping destination located on Fifth Avenue in New York City.'}, {'entity_name': 'Restaurants', 'entity_type': 'AMENITY', 'entity_description': 'Notable dining options available at Hotel Edison.'}, {'entity_name': 'Jazz Bar', 'entity_type': 'AMENITY', 'entity_description': 'A notable jazz bar located within Hotel Edison.'}], 'relationships': [{'source_entity': 'Hotel Edison', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Edison', 'target_entity': 'Time Warner Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Edison', 'target_entity': 'Rockefeller Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Edison', 'target_entity': 'MoMA', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Edison', 'target_entity': 'Fifth Avenue Shops', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Edison', 'target_entity': 'Restaurants', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hotel Edison', 'target_entity': 'Jazz Bar', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 21/149: Moxy NYC Times Square
# Processing and saving result {'entities': [{'entity_name': 'Moxy NYC Times Square', 'entity_type': 'HOTEL', 'entity_description': 'A spirited alternative to the typical hotel experience, Moxy NYC Times Square dazzles with surprises and thrills. Situated in the heart of Midtown, under the shimmering lights of Times Square, offering guests intimate access to Manhattan must-sees.'}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Located in the heart of Midtown, under the shimmering lights, offering access to Manhattan must-sees.'}, {'entity_name': 'Madison Square Garden', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A must-see location in Manhattan, accessible from Moxy NYC Times Square.'}, {'entity_name': 'Rockefeller Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A must-see location in Manhattan, accessible from Moxy NYC Times Square.'}, {'entity_name': 'Broadway', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A must-see location in Manhattan, accessible from Moxy NYC Times Square.'}, {'entity_name': 'Magic Hour', 'entity_type': 'AMENITY', 'entity_description': 'The largest rooftop bar of its kind in NYC, offering epic skyline views and amusement park-style fun.'}, {'entity_name': 'Legasea', 'entity_type': 'AMENITY', 'entity_description': 'A trendy seafood eatery, part of the array of restaurants by Tao Group.'}, {'entity_name': 'Bar Moxy', 'entity_type': 'AMENITY', 'entity_description': 'A collaborative workspace by day and buzzing lounge at night, part of the array of restaurants by Tao Group.'}, {'entity_name': 'Blind Barber', 'entity_type': 'AMENITY', 'entity_description': 'A place to stop for a new style or shave.'}], 'relationships': [{'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Madison Square Garden', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Rockefeller Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Broadway', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Magic Hour', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Legasea', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Bar Moxy', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Moxy NYC Times Square', 'target_entity': 'Blind Barber', 'relationship_type': 'HAS_AMENITY'}]}
# Skipping hotel 22/149: Park Central Hotel New York (no description)
# Processing hotel 23/149: Pod Times Square
# Processing and saving result {'entities': [{'entity_name': 'Pod Times Square', 'entity_type': 'HOTEL', 'entity_description': 'Pod Times Square is the newest member of the Pod Hotel family. Set in the crossroads of the world, close to all of the action, but just far enough away — and above — the hustle and bustle so you can sleep tight and stay happy!'}, {'entity_name': 'Hudson River Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A tranquil park located near Pod Times Square.'}, {'entity_name': 'Intrepid', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A nearby tourist attraction to Pod Times Square.'}, {'entity_name': 'Circle Line Cruises', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A nearby tourist attraction offering cruises, located near Pod Times Square.'}, {'entity_name': '42nd Street – Port Authority subway and bus station', 'entity_type': 'AMENITY', 'entity_description': 'A subway and bus station located one block from Pod Times Square, providing quick and easy access to every neighborhood in New York City and beyond.'}], 'relationships': [{'source_entity': 'Pod Times Square', 'target_entity': 'Hudson River Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Pod Times Square', 'target_entity': 'Intrepid', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Pod Times Square', 'target_entity': 'Circle Line Cruises', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Pod Times Square', 'target_entity': '42nd Street – Port Authority subway and bus station', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 24/149: The New Yorker, A Wyndham Hotel
# Processing and saving result {'entities': [{'entity_name': 'The New Yorker, A Wyndham Hotel', 'entity_type': 'HOTEL', 'entity_description': 'The New Yorker Hotel is one of the most popular hotels in New York City. It offers newly renovated and upgraded guest rooms and suites with contemporary comforts for business travelers.'}, {'entity_name': 'New York City', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major city known for its vibrant culture, iconic landmarks, and as a popular travel destination.'}], 'relationships': [{'source_entity': 'The New Yorker, A Wyndham Hotel', 'target_entity': 'New York City', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 25/149: Hotel Campanile Paris Bercy Village
# Processing and saving result {'entities': [{'entity_name': 'Hotel Campanile Paris Bercy Village', 'entity_type': 'HOTEL', 'entity_description': 'Located in the east of Paris, ideal for exploring the city. Offers proximity to nature and cultural attractions.'}, {'entity_name': 'Bercy Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A park with four gardens, ideal for nature lovers and walking.'}, {'entity_name': 'Cour Saint Emilion', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A village area known for its restaurants and cafes, suitable for strolling.'}], 'relationships': [{'source_entity': 'Hotel Campanile Paris Bercy Village', 'target_entity': 'Bercy Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Campanile Paris Bercy Village', 'target_entity': 'Cour Saint Emilion', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 26/149: St Christopher's Gare du Nord Paris
# Processing and saving result {'entities': [{'entity_name': "St Christopher's Gare du Nord Paris", 'entity_type': 'HOTEL', 'entity_description': "Award winning hostel only 200 metres from the Gare du nord. Great facilities including FREE wifi and Modern 'Pod' beds with USB chargers. Our next generation hostel has a wide range of rooms from female only to double & twin rooms with private bathrooms. Every room includes heating, electronic key security, secure locker storage, private or shared bathrooms and modern hostel POD beds with curtains in dormitories."}, {'entity_name': 'FREE Wifi', 'entity_type': 'AMENITY', 'entity_description': 'Great facilities including FREE wifi.'}, {'entity_name': "Modern 'Pod' Beds", 'entity_type': 'AMENITY', 'entity_description': "Modern 'Pod' beds with USB chargers. Modern hostel POD beds with curtains in dormitories."}, {'entity_name': "Belushi's", 'entity_type': 'AMENITY', 'entity_description': "Paris' biggest expat bar Belushi's - where you'll meet locals and travellers."}, {'entity_name': 'Gare du Nord', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Only 200 metres from the Gare du nord.'}], 'relationships': [{'source_entity': "St Christopher's Gare du Nord Paris", 'target_entity': 'FREE Wifi', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': "St Christopher's Gare du Nord Paris", 'target_entity': "Modern 'Pod' Beds", 'relationship_type': 'HAS_AMENITY'}, {'source_entity': "St Christopher's Gare du Nord Paris", 'target_entity': "Belushi's", 'relationship_type': 'HAS_AMENITY'}, {'source_entity': "St Christopher's Gare du Nord Paris", 'target_entity': 'Gare du Nord', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 27/149: Pullman Paris Eiffel Tower Hotel
# Processing and saving result {'entities': [{'entity_name': 'Pullman Paris Eiffel Tower Hotel', 'entity_type': 'HOTEL', 'entity_description': 'The favorite hotel for travelers to Paris, located at the foot of the Eiffel Tower. It offers great comfort, excellent value for money, and a wide range of services including 24-hour reception, concierge, room service, spacious and bright rooms with a flat-screen TV, WiFi connection, minibar, and docking station for Alexa by Amazon. Some rooms offer a breathtaking view of the Eiffel Tower. The hotel also features FRAME, a Californian brasserie, and a fitness room with hi-tech equipment.'}, {'entity_name': 'Eiffel Tower', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A world-famous landmark located in Paris, near the Pullman Paris Eiffel Tower Hotel.'}, {'entity_name': 'FRAME', 'entity_type': 'AMENITY', 'entity_description': 'A Californian brasserie located within the Pullman Paris Eiffel Tower Hotel, offering brunch or dinner with fresh produce from the garden.'}, {'entity_name': 'Fitness Room', 'entity_type': 'AMENITY', 'entity_description': 'A facility within the Pullman Paris Eiffel Tower Hotel equipped with hi-tech equipment for guests to use.'}], 'relationships': [{'source_entity': 'Pullman Paris Eiffel Tower Hotel', 'target_entity': 'Eiffel Tower', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Pullman Paris Eiffel Tower Hotel', 'target_entity': 'FRAME', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Pullman Paris Eiffel Tower Hotel', 'target_entity': 'Fitness Room', 'relationship_type': 'HAS_AMENITY'}]}
# Skipping hotel 28/149: Citadines Tour Eiffel Paris (no description)
# Processing hotel 29/149: Grand Hotel Malher
# Processing and saving result {'entities': [{'entity_name': 'Grand Hotel Malher', 'entity_type': 'HOTEL', 'entity_description': 'A family establishment for the past 3 generations, located in the heart of the Marais area. The hotel is undergoing renovations to become a 3-star hotel, with new rooms, bathrooms, and furniture featuring modern and elegant design. Breakfast is served in a 17th-century wine cellar.'}, {'entity_name': 'Place des Vosges', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A historic square located near the Grand Hotel Malher.'}, {'entity_name': 'Bastille Opera House', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An opera house located near the Grand Hotel Malher.'}, {'entity_name': 'Picasso Museum', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A museum dedicated to the works of Pablo Picasso, located near the Grand Hotel Malher.'}, {'entity_name': 'Carnavalet Museum', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A museum dedicated to the history of Paris, located near the Grand Hotel Malher.'}, {'entity_name': 'Ile Saint Louis', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An island in the Seine River, located near the Grand Hotel Malher.'}, {'entity_name': 'Notre Dame', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A famous cathedral located near the Grand Hotel Malher.'}, {'entity_name': 'Pompidou Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A modern art museum and cultural center located near the Grand Hotel Malher.'}, {'entity_name': 'Grand Louvre', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A world-renowned art museum located near the Grand Hotel Malher.'}, {'entity_name': 'Saint Paul Metro Station', 'entity_type': 'AMENITY', 'entity_description': 'A metro station located 2 minutes from the Grand Hotel Malher.'}, {'entity_name': '17th Century Wine Cellar', 'entity_type': 'AMENITY', 'entity_description': 'A historic wine cellar where breakfast is served at the Grand Hotel Malher.'}], 'relationships': [{'source_entity': 'Grand Hotel Malher', 'target_entity': 'Place des Vosges', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Bastille Opera House', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Picasso Museum', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Carnavalet Museum', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Ile Saint Louis', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Notre Dame', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Pompidou Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Grand Louvre', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': 'Saint Paul Metro Station', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Grand Hotel Malher', 'target_entity': '17th Century Wine Cellar', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 30/149: St Christopher's Inn Canal Paris
# ...
# Processing hotel 149/149: Hotel Emblem San Francisco
# Processing and saving result {'entities': [{'entity_name': 'Hotel Emblem San Francisco', 'entity_type': 'HOTEL', 'entity_description': 'Hotel Emblem San Francisco in downtown San Francisco where Nob Hill meets Union Square and the Theater District, is a haven for those that think as boldly as they live. Inspiring conversation in all the right ways, with plenty of modern provocations, Hotel Emblem features a cocktail-focused restaurant and 96 vibrant guestrooms. Every corner is designed to spark creativity, from the bar inspired by the Beat Generation, to the book-filled Writer’s Alcove in the lobby, to the eclectic guestrooms, where patterns play and an expressive vibe thrives.'}, {'entity_name': 'Cocktail-focused Restaurant', 'entity_type': 'AMENITY', 'entity_description': 'A restaurant within Hotel Emblem that focuses on cocktails.'}, {'entity_name': 'Vibrant Guestrooms', 'entity_type': 'AMENITY', 'entity_description': '96 vibrant guestrooms in Hotel Emblem designed to spark creativity.'}, {'entity_name': 'Bar Inspired by the Beat Generation', 'entity_type': 'AMENITY', 'entity_description': 'A bar within Hotel Emblem inspired by the Beat Generation.'}, {'entity_name': 'Writer’s Alcove', 'entity_type': 'AMENITY', 'entity_description': 'A book-filled alcove in the lobby of Hotel Emblem.'}, {'entity_name': 'Nob Hill', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A neighborhood in San Francisco near Hotel Emblem.'}, {'entity_name': 'Union Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A famous public plaza in San Francisco near Hotel Emblem.'}, {'entity_name': 'Theater District', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A district in San Francisco known for its theaters, located near Hotel Emblem.'}], 'relationships': [{'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Cocktail-focused Restaurant', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Vibrant Guestrooms', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Bar Inspired by the Beat Generation', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Writer’s Alcove', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Nob Hill', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Union Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Hotel Emblem San Francisco', 'target_entity': 'Theater District', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 150/149: Ritz Carlton Hotel
# Processing and saving result {'entities': [{'entity_name': 'Ritz Carlton Hotel', 'entity_type': 'HOTEL', 'entity_description': 'The 5 stars Ritz Carlton Hotel is located in Nob Hill.'}, {'entity_name': 'Nob Hill', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Nob Hill is a neighborhood in San Francisco known for its luxury hotels and historic landmarks.'}, {'entity_name': 'Grant Plaza Hotel', 'entity_type': 'HOTEL', 'entity_description': 'Grant Plaza Hotel is located 1 block from the Ritz Carlton Hotel.'}], 'relationships': [{'source_entity': 'Ritz Carlton Hotel', 'target_entity': 'Nob Hill', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Ritz Carlton Hotel', 'target_entity': 'Grant Plaza Hotel', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 151/149: Crowne Plaza Times Square Manhattan
# Processing and saving result {'entities': [{'entity_name': 'Crowne Plaza Times Square Manhattan', 'entity_type': 'HOTEL', 'entity_description': "Nestled in the heart of Midtown, our hotel puts you directly on Broadway between 48th and 49th Streets at the doorstep of Times Square. Stay steps from the greatest musical theater in the world, surrounded by iconic New York landmarks, top Fortune 500 companies, and the city's best shopping. Perfecting the art of blended travel, our hotel puts you blocks from Central Park, Rockefeller Center, and Radio City Music Hall. When you're not exploring or heading to a meeting, unwind in spacious rooms with all the essentials, including workspaces. Relax, take in the city, and leave the details to us."}, {'entity_name': 'Times Square', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The doorstep of Times Square, surrounded by iconic New York landmarks and the greatest musical theater in the world.'}, {'entity_name': 'Central Park', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Blocks from the hotel, a famous urban park in New York City.'}, {'entity_name': 'Rockefeller Center', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Blocks from the hotel, a large complex consisting of 19 commercial buildings.'}, {'entity_name': 'Radio City Music Hall', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Blocks from the hotel, an entertainment venue located in Rockefeller Center.'}, {'entity_name': 'Workspaces', 'entity_type': 'AMENITY', 'entity_description': 'Spacious rooms with all the essentials, including workspaces.'}], 'relationships': [{'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Times Square', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Central Park', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Rockefeller Center', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Radio City Music Hall', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Times Square Manhattan', 'target_entity': 'Workspaces', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 152/149: Crowne Plaza Istanbul - Florya
# Processing and saving result {'entities': [{'entity_name': 'Crowne Plaza Istanbul - Florya', 'entity_type': 'HOTEL', 'entity_description': 'Stylish seaside hotel with an outdoor pool and meeting facilities, next to Istanbul Aquarium and Aqua Florya Mall. Ideal for business and leisure travellers, Crowne Plaza® Istanbul - Florya hotel is a 15-minute drive from CNR Expo and IDTM exhibition centres. We provide free parking in our secure lot. Transport links by bus, train and road are excellent. We have six fully equipped meeting rooms with a maximum capacity of 800, while our outdoor banquet area has room for 1,250 guests. Our Crowne Plaza Meetings Director is on hand to take care of all the details. The hotel has free Wi-Fi throughout and is completely connected, providing access to power when and where you need it.'}, {'entity_name': 'Outdoor Pool', 'entity_type': 'AMENITY', 'entity_description': 'Outdoor pool available at the hotel.'}, {'entity_name': 'Meeting Facilities', 'entity_type': 'AMENITY', 'entity_description': 'Meeting facilities available at the hotel, including six fully equipped meeting rooms with a maximum capacity of 800 and an outdoor banquet area for 1,250 guests.'}, {'entity_name': 'Istanbul Aquarium', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Tourist attraction located next to the hotel.'}, {'entity_name': 'Aqua Florya Mall', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Shopping mall located next to the hotel.'}, {'entity_name': 'CNR Expo', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Exhibition centre located a 15-minute drive from the hotel.'}, {'entity_name': 'IDTM', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Exhibition centre located a 15-minute drive from the hotel.'}, {'entity_name': 'Free Parking', 'entity_type': 'AMENITY', 'entity_description': "Free parking available in the hotel's secure lot."}, {'entity_name': 'Free Wi-Fi', 'entity_type': 'AMENITY', 'entity_description': 'Free Wi-Fi available throughout the hotel.'}], 'relationships': [{'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'Outdoor Pool', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'Meeting Facilities', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'Istanbul Aquarium', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'Aqua Florya Mall', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'CNR Expo', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'IDTM', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'Free Parking', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Crowne Plaza Istanbul - Florya', 'target_entity': 'Free Wi-Fi', 'relationship_type': 'HAS_AMENITY'}]}
# Processing hotel 153/149: Holiday Inn London - West
# Processing and saving result {'entities': [{'entity_name': 'Holiday Inn London - West', 'entity_type': 'HOTEL', 'entity_description': 'Holiday Inn London - West, an IHG Hotel, offers a fantastic arrival experience with a beautifully designed Open Lobby and stunning brand new Executive Rooms, some with London skyline views. Conveniently located between Heathrow Airport and the centre of London.'}, {'entity_name': 'Open Lobby', 'entity_type': 'AMENITY', 'entity_description': 'A beautifully designed lobby area within the Holiday Inn London - West.'}, {'entity_name': 'Executive Rooms', 'entity_type': 'AMENITY', 'entity_description': 'Brand new rooms with stunning views of the London skyline, available at the Holiday Inn London - West.'}, {'entity_name': 'Heathrow Airport', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major international airport in London, located near the Holiday Inn London - West.'}, {'entity_name': 'Centre of London', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'The central area of London, located near the Holiday Inn London - West.'}], 'relationships': [{'source_entity': 'Holiday Inn London - West', 'target_entity': 'Open Lobby', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Holiday Inn London - West', 'target_entity': 'Executive Rooms', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Holiday Inn London - West', 'target_entity': 'Heathrow Airport', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Holiday Inn London - West', 'target_entity': 'Centre of London', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 154/149: Ibis London Canning Town
# Processing and saving result {'entities': [{'entity_name': 'Ibis London Canning Town', 'entity_type': 'HOTEL', 'entity_description': 'A hotel offering comfortable accommodations with Sweet Bed, hearty breakfast, and a café bar named Chill #08. Located near Central London with easy access to the O2, ExCeL, and Canning Town tube station.'}, {'entity_name': 'Sweet Bed', 'entity_type': 'AMENITY', 'entity_description': 'Comfortable accommodations feature.'}, {'entity_name': 'Hearty Breakfast', 'entity_type': 'AMENITY', 'entity_description': 'A breakfast offering at the hotel.'}, {'entity_name': 'Chill #08', 'entity_type': 'AMENITY', 'entity_description': 'A café bar at the hotel.'}, {'entity_name': 'Central London', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A major area in London, known for its attractions and activities.'}, {'entity_name': 'O2', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A large entertainment district in London.'}, {'entity_name': 'ExCeL', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'An exhibition and international convention centre in London.'}, {'entity_name': 'Canning Town Tube Station', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A tube station providing easy access to the hotel.'}], 'relationships': [{'source_entity': 'Ibis London Canning Town', 'target_entity': 'Sweet Bed', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Ibis London Canning Town', 'target_entity': 'Hearty Breakfast', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Ibis London Canning Town', 'target_entity': 'Chill #08', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Ibis London Canning Town', 'target_entity': 'Central London', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Ibis London Canning Town', 'target_entity': 'O2', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Ibis London Canning Town', 'target_entity': 'ExCeL', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Ibis London Canning Town', 'target_entity': 'Canning Town Tube Station', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 155/149: Homewood Suites by Hilton New York/Midtown Manhattan Times Square-South
# Processing and saving result {'entities': [{'entity_name': 'Homewood Suites by Hilton New York/Midtown Manhattan Times Square-South', 'entity_type': 'HOTEL', 'entity_description': 'An all-suite, extended-stay hotel conveniently located on the West Side of Manhattan, offering a contemporary base in the heart of The Big Apple.'}, {'entity_name': 'West Side of Manhattan', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'A location in Manhattan where the hotel is conveniently situated.'}, {'entity_name': 'The Big Apple', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': "A nickname for New York City, indicating the hotel's central location."}], 'relationships': [{'source_entity': 'Homewood Suites by Hilton New York/Midtown Manhattan Times Square-South', 'target_entity': 'West Side of Manhattan', 'relationship_type': 'LOCATED_NEARBY'}, {'source_entity': 'Homewood Suites by Hilton New York/Midtown Manhattan Times Square-South', 'target_entity': 'The Big Apple', 'relationship_type': 'LOCATED_NEARBY'}]}
# Processing hotel 156/149: Les Piaules
# Processing and saving result {'entities': [{'entity_name': 'Les Piaules', 'entity_type': 'HOTEL', 'entity_description': 'A new hostel offering a bar and a rooftop terrace with a fantastic view on the iconic monuments of Paris, fast free WiFi, check-out until 12am, custom bunkbeds.'}, {'entity_name': 'Bar', 'entity_type': 'AMENITY', 'entity_description': 'A bar available at the hostel.'}, {'entity_name': 'Rooftop Terrace', 'entity_type': 'AMENITY', 'entity_description': 'A rooftop terrace with a fantastic view on the iconic monuments of Paris.'}, {'entity_name': 'Fast Free WiFi', 'entity_type': 'AMENITY', 'entity_description': 'Fast and free WiFi available at the hostel.'}, {'entity_name': 'Custom Bunkbeds', 'entity_type': 'AMENITY', 'entity_description': 'Custom bunkbeds available at the hostel.'}, {'entity_name': 'Iconic Monuments of Paris', 'entity_type': 'TOURIST_ATTRACTION', 'entity_description': 'Iconic monuments of Paris visible from the rooftop terrace.'}], 'relationships': [{'source_entity': 'Les Piaules', 'target_entity': 'Bar', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Les Piaules', 'target_entity': 'Rooftop Terrace', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Les Piaules', 'target_entity': 'Fast Free WiFi', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Les Piaules', 'target_entity': 'Custom Bunkbeds', 'relationship_type': 'HAS_AMENITY'}, {'source_entity': 'Rooftop Terrace', 'target_entity': 'Iconic Monuments of Paris', 'relationship_type': 'LOCATED_NEARBY'}]}
# Completed batch of 100 hotels

# %% [markdown]
# Our knowledge graph has now been augmented with additional fact triplets about the hotels. This enrichment allows us to capture more complex relationships between hotels, amenities, and tourist attractions.

# %% [markdown]
# ## Build database indices for the graph
#
# With the data in place, we can next create a vector index over the text properties, exposing all of our nodes to HNSW similarity search.
#
# Recall that in our basic KG notebook, we crafted our node MERGE Cypher statement to give all new nodes a base label `__Entity__` along with their type label from our hotels data model. In Neo4j, we can only a create a vector index for a single node label, but we might not know all the entity types we will need ahead of time. Hence why we gave all our nodes a base entity label to cover all potential entity types. Now that we've added new entity and relationship types to our KG, we're ready to create the vector index that will allow us to perform similarity search.

# %%
import os
from langchain.vectorstores.neo4j_vector import Neo4jVector
from langchain.embeddings.openai import OpenAIEmbeddings

vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    url=url,
    username=username,
    password=password,
    index_name='reviews',
    node_label="__Entity__",
    text_node_properties=['name', 'description', 'text'],
    embedding_node_property='embedding',
)
# Out:
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated procedure. ('db.index.vector.createNodeIndex' has been replaced by 'CREATE VECTOR INDEX')} {position: line: 1, column: 1, offset: 0} for query: 'CALL db.index.vector.createNodeIndex($index_name,$node_label,$embedding_node_property,toInteger($embedding_dimension),$similarity_metric )'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated procedure. ('db.create.setVectorProperty' has been replaced by 'db.create.setNodeVectorProperty')} {position: line: 1, column: 72, offset: 71} for query: "UNWIND $data AS row MATCH (n:`__Entity__`) WHERE elementId(n) = row.id CALL db.create.setVectorProperty(n, 'embedding', row.embedding) YIELD node RETURN count(*)"
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated procedure. ('db.create.setVectorProperty' has been replaced by 'db.create.setNodeVectorProperty')} {position: line: 1, column: 72, offset: 71} for query: "UNWIND $data AS row MATCH (n:`__Entity__`) WHERE elementId(n) = row.id CALL db.create.setVectorProperty(n, 'embedding', row.embedding) YIELD node RETURN count(*)"

# %%
# Test the vector search capability with a dash of Langchain
response = vector_index.similarity_search(
    "What positive things are said about the Pera Palace Hotel?"
)

print("Top similarity search result:")
print(response[0].page_content)
# Out:
# Top similarity search result:
#
# name: Pera Perfect\$
# description:
# text: Gamze went above and beyond to make all our dining experiences superb at the Pera Palace Hotel. She is most attentive to one's needs and a true asset to the hotel. Our room was clean, comfortable, spacious , and yet reminiscent of a bygone era.  Afternoon tea, accompanied by piano music, was delightful. The  Ataturk quarters were historical and the famous elevator, 1 of the 1st of its kind in Europe, are a must see. \$

# %% [markdown]
# # Advanced Retrieval

# %% [markdown]
# ## Text2Cypher: Building a Flexible Retrieval Pattern
#
# In the basic notebook, we explored a template-based approach to graph retrieval, which works well for common query patterns with clear entities. However, template-based systems are limited to predefined patterns and can't handle novel queries or complex structural relationships.
#
# Text2Cypher is a more flexible retrieval pattern that uses an LLM to generate custom Cypher queries on the fly based on:
# 1. The natural language query
# 2. The graph schema
# 3. Best practices for Cypher query construction
#
# Our applications gain several advantages from this approach:
# - **Flexibility**: Can handle arbitrary query patterns not covered by templates
# - **Structural Understanding**: Maintains awareness of the graph structure
# - **Complex Relationships**: Supports multi-hop traversals and complex filtering
#
# The implementation involves:
# 1. Fetching the graph schema from Neo4j
# 2. Using the schema to guide the LLM in generating valid Cypher
# 3. Executing the generated Cypher and processing the results
# 4. Generating a natural language answer from the structured results
#
# Let's implement a Text2Cypher retriever from scratch:

# %% [markdown]
# ### Text2Cypher retriever

# %%
import os
from typing import List, Dict, Any, Optional, Union
from openai import OpenAI
import json
from neo4j import GraphDatabase

class Text2CypherRetriever:
    """
    A retriever that converts natural language queries to Cypher queries using LLMs.
    """

    def __init__(self, neo4j_driver: GraphDatabase.driver, openai_client: OpenAI, schema: Optional[str] = None):
        """
        Initialize the Text2Cypher retriever.

        Args:
            neo4j_driver: Neo4j database driver
            openai_client: OpenAI client
            schema: Optional schema information to guide Cypher generation.
                   If None, the schema will be fetched from the database.
        """
        self.driver = neo4j_driver
        self.client = openai_client
        self._schema = schema

    @property
    def schema(self) -> str:
        """Get the Neo4j schema information."""
        if self._schema is None:
            self._schema = self._fetch_schema()
        return self._schema

    def _fetch_schema(self) -> str:
        """Fetch the graph schema information from the Neo4j database."""
        with self.driver.session() as session:
            # Get node labels, properties, and relationship types
            result = session.run("""
            CALL apoc.meta.schema()
            YIELD value
            RETURN value
            """)

            schema_data = result.single()["value"]

            # Format the schema in a way that's easy for the LLM to understand
            formatted_schema = "# Node Labels and Properties\n"

            for node_label, node_data in schema_data.items():
                if node_data.get("type") == "node":
                    formatted_schema += f"\n## {node_label}\n"
                    formatted_schema += "Properties:\n"

                    for prop, prop_data in node_data.get("properties", {}).items():
                        if prop != "embedding":  # Skip embedding properties
                            formatted_schema += f"- {prop}: {prop_data.get('type', 'unknown')}\n"

            formatted_schema += "\n# Relationship Types\n"
            rels = set()

            for node_data in schema_data.values():
                if node_data.get("type") == "node":
                    for rel in node_data.get("relationships", {}).values():
                        rel_type = rel.get("type")
                        if rel_type:
                            rels.add(rel_type)

            for rel in sorted(rels):
                formatted_schema += f"- {rel}\n"

            return formatted_schema

    def generate_cypher(self, query: str) -> str:
        """
        Generate a Cypher query from a natural language query.

        Args:
            query: Natural language query

        Returns:
            Generated Cypher query
        """
        prompt = f"""You are a Neo4j Cypher query expert. Your task is to translate natural language questions into Cypher queries.

Below is the schema of the Neo4j graph database:

{self.schema}

Important Guidelines:
1. Generate only the Cypher query, with no explanations, comments, or markdown formatting.
2. Always return nodes with all their properties to provide complete information.
3. Avoid using the 'embedding' property in your queries - it contains vector data and is very large.
4. Use appropriate aggregation functions (count, avg, collect) when grouping data.
5. Limit results to a reasonable number (10-20 max) when returning many nodes.
6. For more complex queries, consider using multiple MATCH clauses.
7. Make sure to use the correct relationship directions in your query.

Question: {query}

Cypher Query:"""

        response = self.client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0,
            messages=[
                {"role": "system", "content": "You are a Neo4j Cypher query generation assistant."},
                {"role": "user", "content": prompt}
            ]
        )

        cypher_query = response.choices[0].message.content.strip()

        # Clean up any markdown formatting if present
        if cypher_query.startswith("```") and cypher_query.endswith("```"):
            cypher_query = cypher_query[3:-3].strip()
        if cypher_query.startswith("```cypher"):
            cypher_query = cypher_query[9:].strip()
            if cypher_query.endswith("```"):
                cypher_query = cypher_query[:-3].strip()

        return cypher_query

    def execute_cypher(self, cypher_query: str) -> List[Dict[str, Any]]:
        """
        Execute a Cypher query against the Neo4j database.

        Args:
            cypher_query: Cypher query to execute

        Returns:
            List of result records as dictionaries
        """
        try:
            with self.driver.session() as session:
                result = session.run(cypher_query)
                records = [dict(record) for record in result]
                return records
        except Exception as e:
            print(f"Error executing Cypher query: {str(e)}")
            return []

    def retrieve(self, query: str) -> Dict[str, Any]:
        """
        Retrieve information from the Neo4j database using a natural language query.

        Args:
            query: Natural language query

        Returns:
            Dictionary containing the results and query information
        """
        # Generate Cypher query
        cypher_query = self.generate_cypher(query)

        # Execute the query
        results = self.execute_cypher(cypher_query)

        return {
            "query": query,
            "cypher_query": cypher_query,
            "results": results
        }

    def generate_answer(self, query: str, results: List[Dict[str, Any]]) -> str:
        """
        Generate a natural language answer based on query results.

        Args:
            query: Original natural language query
            results: Query results

        Returns:
            Natural language answer
        """
        # Format results for the prompt
        if not results:
            results_text = "No results were found for this query."
        else:
            # Convert results to a clean text representation
            items = []
            for i, item in enumerate(results[:10]):  # Limit to 10 items to keep prompt size reasonable
                item_str = f"Result {i+1}:\n"
                for k, v in item.items():
                    if k == "embedding":
                        continue  # Skip embedding vectors
                    if isinstance(v, (list, set)):
                        v_str = ", ".join(str(x) for x in v if x is not None)
                        item_str += f"  {k}: {v_str}\n"
                    else:
                        item_str += f"  {k}: {v}\n"
                items.append(item_str)

            if len(results) > 10:
                items.append(f"... and {len(results) - 10} more results.")

            results_text = "\n".join(items)

        prompt = f"""
The user asked: "{query}"

I retrieved the following information from the graph database:
{results_text}

Based on this information, provide a helpful, conversational response to the user's query.
Make sure to address all aspects of their question if possible.
If the information retrieved doesn't fully answer their query, acknowledge this limitation.
"""

        response = self.client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0.7,
            messages=[
                {"role": "system", "content": "You are a helpful assistant that provides accurate information based on database query results."},
                {"role": "user", "content": prompt}
            ]
        )

        return response.choices[0].message.content

    def query(self, query: str) -> Dict[str, Any]:
        """
        Process a natural language query end-to-end.

        Returns:
            Dictionary with answer, retrieval info, and intermediate steps
        """
        # Retrieve information
        retrieval_result = self.retrieve(query)

        # Generate answer
        answer = self.generate_answer(query, retrieval_result["results"])

        return {
            "query": query,
            "answer": answer,
            "retrieval_info": {
                "cypher_query": retrieval_result["cypher_query"],
                "result_count": len(retrieval_result["results"])
            },
            "results": retrieval_result["results"]
        }

# %% [markdown]
# Now let's initialize and test our Text2Cypher retriever:

# %%
text2cypher_retriever = Text2CypherRetriever(
    neo4j_driver=driver,
    openai_client=openai_client
)

# %%
text2cypher_retriever.query("What tourist attractions are LOCATED NEARBY the Grant Plaza Hotel?")
# Out:
# {'query': 'What tourist attractions are LOCATED NEARBY the Grant Plaza Hotel?',
#  'answer': "Certainly! If you’re staying at the Grant Plaza Hotel, there are some great tourist attractions nearby that you can explore:\n\n1. **Chinatown**: Just a short walk away, Chinatown is a vibrant neighborhood in San Francisco known for its colorful streets and numerous shops and restaurants. It’s a fantastic place to immerse yourself in culture and enjoy some delicious cuisine.\n\n2. **San Francisco Cable Car**: The famous San Francisco Cable Car line is just one block from the Grant Plaza Hotel. Riding the cable car is a quintessential San Francisco experience, offering scenic views of the city as it climbs the hills.\n\n3. **Bank of America Building**: Also located just one block away, the Bank of America Building is situated in the Financial District. While it may not be a traditional tourist attraction, it's noteworthy for its architecture and proximity to other attractions.\n\n4. **Union Square**: Although it's mentioned that Union Square is near Hotel Emblem, it’s still relatively close to the Grant Plaza Hotel as well. It’s a major shopping and cultural hub in San Francisco, featuring a variety of shops, galleries, and theaters.\n\nThese attractions provide a mix of cultural experiences and iconic sights, all within easy reach of your hotel. Enjoy your visit! If you have any more questions or need further recommendations, feel free to ask!",
#  'retrieval_info': {'cypher_query': "MATCH (h:HOTEL {name: 'Grant Plaza Hotel'})-[:LOCATED_NEARBY]->(ta:TOURIST_ATTRACTION) \nRETURN ta",
#   'result_count': 4},
#  'results': [{'ta': <Node element_id='4:d2e43e95-dd9c-4a42-804b-8792143bb53e:639' labels=frozenset({'__Entity__', 'TOURIST_ATTRACTION'}) properties={'name': 'Chinatown', 'description': 'Colorful neighborhoods in San Francisco, known for its many streets to explore.', 'entity': 'TOURIST_ATTRACTION'}>},
#   {'ta': <Node element_id='4:d2e43e95-dd9c-4a42-804b-8792143bb53e:650' labels=frozenset({'__Entity__', 'TOURIST_ATTRACTION'}) properties={'name': 'Union Square', 'description': 'A major tourist attraction in San Francisco located near Hotel Emblem.', 'entity': 'TOURIST_ATTRACTION'}>},
#   {'ta': <Node element_id='4:d2e43e95-dd9c-4a42-804b-8792143bb53e:789' labels=frozenset({'__Entity__', 'TOURIST_ATTRACTION'}) properties={'name': 'San Francisco Cable Car', 'description': 'The famous San Francisco Cable Car line is 1 block from Grant Plaza Hotel.', 'entity': 'TOURIST_ATTRACTION'}>},
#   {'ta': <Node element_id='4:d2e43e95-dd9c-4a42-804b-8792143bb53e:790' labels=frozenset({'__Entity__', 'TOURIST_ATTRACTION'}) properties={'name': 'Bank of American Building', 'description': 'The Bank of American Building is in the Financial District, 1 block from Grant Plaza Hotel.', 'entity': 'TOURIST_ATTRACTION'}>}]}

# %% [markdown]
# ## Basic Vector Similarity Retriever Implementation

# %% [markdown]
# Let's implement a retriever that uses vector similarity to find relevant nodes in the graph:

# %%
class VectorSimilarityRetriever:
    def __init__(self, neo4j_driver: GraphDatabase.driver, openai_client: OpenAI, index_name: str = "reviews"):
        """
        Initialize the vector similarity retriever.

        Args:
            neo4j_driver: Neo4j database driver
            openai_client: OpenAI client
            index_name: Name of the vector index in Neo4j
        """
        self.driver = neo4j_driver
        self.client = openai_client
        self.index_name = index_name
        self.embeddings_model = "text-embedding-ada-002"

    def get_embedding(self, text: str) -> List[float]:
        """
        Get an embedding vector for the given text.

        Args:
            text: Text to embed

        Returns:
            Embedding vector
        """
        response = self.client.embeddings.create(
            model=self.embeddings_model,
            input=text
        )
        return response.data[0].embedding

    def retrieve(self, query: str, limit: int = 10, node_labels: Optional[List[str]] = None) -> Dict[str, Any]:
        """
        Retrieve nodes from the graph based on vector similarity.

        Args:
            query: Query text
            limit: Maximum number of results to return
            node_labels: Optional list of node labels to filter by

        Returns:
            Dictionary containing the results and query information
        """
        # Get embedding for the query
        query_embedding = self.get_embedding(query)

        # Construct Neo4j query for vector search with more targeted results
        cypher_query = f"""
        CALL db.index.vector.queryNodes($index_name, $limit, $query_embedding)
        YIELD node, score
        """

        # Add label filter if provided, otherwise prioritize REVIEW nodes for text queries
        if node_labels:
            label_filters = []
            for label in node_labels:
                label_filters.append(f"node:{label}")
            cypher_query += f"WHERE {' OR '.join(label_filters)}\n"
        else:
            # For review-specific queries, prioritize REVIEW nodes
            if "review" in query.lower() or "said" in query.lower() or "sentiment" in query.lower():
                cypher_query += "WHERE node:REVIEW\n"

        cypher_query += """
        RETURN node, score
        ORDER BY score DESC
        """

        # Execute query
        try:
            with self.driver.session() as session:
                result = session.run(
                    cypher_query,
                    index_name=self.index_name,
                    limit=limit,
                    query_embedding=query_embedding
                )

                # Transform the results into a more usable format
                records = []
                for record in result:
                    node = record["node"]
                    score = record["score"]

                    # Extract all node properties
                    props = dict(node)
                    if "embedding" in props:
                        del props["embedding"]  # Skip embedding vectors

                    # Add score and labels
                    props["similarity_score"] = score
                    props["labels"] = list(node.labels)

                    records.append(props)

                return {
                    "query": query,
                    "results": records
                }
        except Exception as e:
            print(f"Error executing vector search: {str(e)}")
            return {
                "query": query,
                "error": str(e),
                "results": []
            }

    def generate_answer(self, query: str, results: List[Dict[str, Any]]) -> str:
        """
        Generate a natural language answer based on query results.

        Args:
            query: Original natural language query
            results: Query results

        Returns:
            Natural language answer
        """
        # Format results for the prompt
        if not results:
            results_text = "No results were found for this query."
        else:
            # Convert results to a clean text representation
            items = []
            for i, item in enumerate(results[:5]):  # Limit to 5 items
                item_str = f"Result {i+1} (Similarity: {item.get('similarity_score', 'N/A')}):\n"
                for k, v in item.items():
                    if k in ['embedding', 'similarity_score']:
                        continue  # Skip embedding vectors and already displayed score
                    if isinstance(v, (list, set)):
                        v_str = ", ".join(str(x) for x in v if x is not None)
                        item_str += f"  {k}: {v_str}\n"
                    else:
                        item_str += f"  {k}: {v}\n"
                items.append(item_str)

            if len(results) > 10:
                items.append(f"... and {len(results) - 10} more results.")

            results_text = "\n".join(items)

        prompt = f"""
The user asked: "{query}"

I retrieved the following information using semantic similarity search:
{results_text}

Based on this information, provide a helpful, conversational response to the user's query.
Focus on the most relevant information from the results.
If the information retrieved doesn't fully answer their query, acknowledge this limitation.
"""

        response = self.client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0.7,
            messages=[
                {"role": "system", "content": "You are a helpful assistant that provides accurate information based on semantic search results."},
                {"role": "user", "content": prompt}
            ]
        )

        return response.choices[0].message.content

    def query(self, query: str, limit: int = 10, node_labels: Optional[List[str]] = None) -> Dict[str, Any]:
        """
        Process a natural language query end-to-end.

        Args:
            query: Natural language query
            limit: Maximum number of results to return
            node_labels: Optional list of node labels to filter by

        Returns:
            Dictionary with answer, retrieval info, and results
        """
        # Retrieve information
        retrieval_result = self.retrieve(query, limit, node_labels)

        # Generate answer
        answer = self.generate_answer(query, retrieval_result["results"])

        return {
            "query": query,
            "answer": answer,
            "retrieval_info": {
                "retrieval_method": "vector_similarity",
                "result_count": len(retrieval_result["results"])
            },
            "results": retrieval_result["results"]
        }

# %%
vector_retriever = VectorSimilarityRetriever(
    neo4j_driver=driver,
    openai_client=openai_client
)

vector_retriever.query("What positive things are said about the Sirdeci Mansion Hotel?")
# Out:
# {'query': 'What positive things are said about the Sirdeci Mansion Hotel?',
#  'answer': "The Sirdeci Mansion Hotel has received many positive reviews from guests, highlighting several aspects that make it a great choice for a stay in Istanbul.\n\n1. **Location**: Guests rave about the hotel's prime location in the old area of Istanbul. It's within walking distance to major attractions like the Blue Mosque, Topkapi Palace, and the Grand Bazaar. This makes it very convenient for exploring the city's rich history and culture.\n\n2. **Friendly and Helpful Staff**: Many reviews emphasize the exceptional service provided by the hotel staff. Guests mention how welcoming and accommodating the staff are, going out of their way to help with directions, recommendations, and even booking tables at nearby restaurants. Specific staff members, like Okay and Fatme, received special mentions for their attentiveness and helpfulness.\n\n3. **Comfortable and Unique Accommodations**: Reviewers appreciate the traditional mansion feel of the hotel, with spacious rooms that stand out in a capital city. The hotel also features a lovely rooftop terrace, a hammam, a pool, and a sauna, creating a relaxing oasis for guests.\n\n4. **Delicious Breakfast**: Many guests have highlighted the quality of the breakfast, describing it as excellent and a great way to start the day.\n\n5. **Overall Experience**: Overall, guests have consistently rated their experiences highly, with many stating they would recommend the hotel and return for future visits. The combination of location, staff service, and amenities seems to create a memorable stay.\n\nWhile the reviews are overwhelmingly positive, it's worth noting that some guests felt the hotel may not fully meet a 4-star standard in terms of facilities, though they were quick to praise the staff's service as deserving of 5 stars.\n\nIf you're considering a stay at the Sirdeci Mansion Hotel, it sounds like you can expect a warm welcome and a great location to explore Istanbul!",
#  'retrieval_info': {'retrieval_method': 'vector_similarity',
#   'result_count': 9},
#  'results': [{'color': 'orange',
#    'size': 15,
#    'tripdate': 'Fall 2023',
#    'rating_value': 5.0,
#    'name': 'Beautiful boutique hotel in vibrant Istanbul\\$',
#    'text': 'Sirkeci Mansion is perfectly located in the old area of Istanbul. We walked to the Blue Mosque, Topkapi Palace, Hagia Sofia, Gulhane Park, the Grand Bazaar, the Spice Market and to the Bosphorus River for a river cruise. There are so many restaurants a few steps from the hotel and shopping all around.  The staff are very welcoming and so helpful in giving directions and recommendations. We arrived after 10 pm and they quickly booked a table for us in a nearby rooftop restaurant which was a great start to our stay. Breakfast is delicious. We highly recommend this hotel.\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.9302520751953125,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Winter 2023',
#    'rating_value': 4.5,
#    'name': 'Excellent hotel\\$',
#    'text': 'Good morning, we spent a week and we had a very good time with all the services. We would like to make a special mention for Mrs. Serife who cleaned the room, very good and kind as well as very professional, Luciano and Claudia felice 2024 a tutti\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.921600341796875,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Winter 2023',
#    'rating_value': 4.5,
#    'name': 'great stay, would highly recommend\\$',
#    'text': 'what is there not to like. 1. staff and must mention; Natia, Myriam, Bukat (Bell boy) and of course Akin (evening security\reception.  everyone was just so welcoming and accomodating and will go out of their way to make your stay a great experience. 2. the hotel, however is not worth a 4star by my standard but the staff should be given 5 stars, yes they were that great. 3. would I stay again? - a resounding Yes. 10-15 mins walk to the Grand bazzar and the the other tourist sitres; basilica cister, sofia, blue mosque shops and restaurant within 2 mins walk onsite food on the 7th floor was also great really cannot fault\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.9167022705078125,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Summer 2023',
#    'rating_value': 5.0,
#    'name': 'The best place to stay in Istanbul! No discussion!\\$',
#    'text': 'This was the best hotel in which I have stayed during a three month tour of Europe. Second time I have stayed here... First of all, the staff. All of them super-friendly, very helpful and efficient. Special mention to Okay, whom I remember from my stay in 2013, and who gave us excellent tips for visiting the places of interest, also Fatme who looked after us so well at the (excellent) breakfasts. Secondly the actual hotel. A wonderful traditional mansion with large rooms, unusual in hotels in a capital city, and a cool, welcoming oasis in the heart of the old city. Fantastic rooftop terrace with bar and food. A hammam, pool, Turkish bath, sauna... perfect! And thirdly, its position in the heart of the old city ensured that everything was within a 15 minute walk. Great\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.9161529541015625,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Summer 2023',
#    'rating_value': 5.0,
#    'name': 'Fantastic Hotel\\$',
#    'text': 'Fantastic hotel. We had 2 rooms and stayed 9 nights. The location is in an excellent location for all local attractions. The staff are brilliant and only too willing to help. Elif was great on our first day and explained where we could change money and how to get to local attractions. Selim on the front desk is an absolute gentleman. We had an issue with a taxi driver one of the days and he came out and sorted it out. Highly recommended and I will definitely stay again at the Demiray Hotel when I return to Istanbul. \\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.915374755859375,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Fall 2023',
#    'rating_value': 5.0,
#    'name': 'Great, great and great!\\$',
#    'text': 'Loved my stay here! Super clean and tiny rooms, room service is amazing, breakfast was great, and the staff were absolutely lovely - constantly smiling and making sure we are okay. Felt like home. Very good location and walking distance to most popular locations. Wanted to especially mention Serdar who was extremely kind, attentive and even gave us a long list of recommendations in Istanbul! A beautiful stay would definitely stay here again. Thank you Emrah for your lovely service and the tea! Thank you Demiray :)\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.9151153564453125,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Winter 2024',
#    'rating_value': 4.5,
#    'name': 'Sura Hagia Sofia Hotel Stay\\$',
#    'text': "I recently stayed here for a week and thehotel staff was amazing. Particularly AhmarAli and sheraz and Hassan and Abdullah Ali ❤️ He was so attentive and responsiveanytime I requested something. I really didenjoy my stay here. The people made itworth the experience and trip. I recommendstaying here 100% as it's an amazing hotel\\$",
#    'entity': 'REVIEW',
#    'similarity_score': 0.912841796875,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Winter 2024',
#    'rating_value': 4.5,
#    'name': 'That was awesome experience for me and my family. The hotel was so much clean and comfortable. I really loved the view a\\$',
#    'text': 'The employees were awesome. I can mention Halay and Sevcan were outstanding in their roles.they have a lot of potential and they are very well rounded in their roles and their ability to make the atmosphere feel good is very important. I really enjoyed their performance during my trip.\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.9118804931640625,
#    'labels': ['__Entity__', 'REVIEW']},
#   {'color': 'orange',
#    'size': 15,
#    'tripdate': 'Winter 2024',
#    'rating_value': 5.0,
#    'name': 'Nice hotel\\$',
#    'text': 'Location is very good near historical places and Hagia Sophia and best place Topkapi. Breakfast is good and service is very nice. Room was big and clean. Decoration is cute. Hamam is nice we was relaxed. Staff is very kind and helpful\\$',
#    'entity': 'REVIEW',
#    'similarity_score': 0.9118499755859375,
#    'labels': ['__Entity__', 'REVIEW']}]}

# %% [markdown]
# ## Router Retriever: Your Homework Assignment
# Now that we've implemented three different retrieval strategies, we need a router that can intelligently select the most appropriate strategy for each query. This is where your homework assignment comes in!
# Below is a skeleton implementation of a RouterRetriever class. Your task is to complete the implementation by filling in the missing parts:

# %%
class RouterRetriever:
    """
    A router that selects the appropriate retrieval strategy based on query characteristics.

    This is a skeleton implementation for you to complete as part of the homework assignment.
    """

    def __init__(
        self,
        text2cypher_retriever: Text2CypherRetriever,
        template_retriever: SimpleGraphRAG, # copy from basic notebook
        vector_retriever: VectorSimilarityRetriever,
        openai_client: OpenAI
    ):
        """Initialize with all retriever implementations."""
        self.text2cypher_retriever = text2cypher_retriever
        self.template_retriever = template_retriever
        self.vector_retriever = vector_retriever
        self.client = openai_client

    def route_query(self, query: str) -> Dict[str, Any]:
        """
        Analyze the query and determine which retrieval strategy to use.

        Args:
            query: The natural language query

        Returns:
            Dictionary with the selected strategy and reasoning

        TODO: Implement this method to select the most appropriate retrieval strategy.
        """
        # TODO: Implement query analysis and strategy selection

        # Default implementation (replace with your own)
        return {
            "strategy": "text2cypher",  # Default fallback
            "reasoning": "Default strategy - replace with actual reasoning"
        }

    def query(self, query: str) -> Dict[str, Any]:
        """
        Route the query to the appropriate retriever and return results.

        Args:
            query: The natural language query

        Returns:
            Results from the selected retriever with routing information

        TODO: Complete this method to execute the query using the selected strategy.
        """
        # TODO: Implement query routing
        # 1. Call route_query to determine the best strategy
        # 2. Execute the query using the selected retriever
        # 3. Return the results with added routing information

        # Default implementation (replace with your own)
        strategy = "text2cypher"  # Replace with actual routing logic
        result = self.text2cypher_retriever.query(query)

        # TODO: Add routing information to the result

        return result

# %% [markdown]
# ### Assignment Guidelines:
#
# 1. **Strategy Selection Logic:** Implement route_query to intelligently analyze the query and select the most appropriate retrieval strategy.
#
#   * Document your reasoning process for different query types
#
#
# 2. **Router Implementation:** Complete the query method to route queries to the appropriate retriever.
#
#   * Handle errors gracefully if a strategy fails
#   * Provide clear metadata about why a particular strategy was chosen
#   * Consider implementing fallback strategies
#
#
# 3. **Testing and Evaluation:**
#
#   * Test your router with a variety of queries
#   * Compare the results from different strategies
#   * Evaluate the accuracy of your strategy selection logic
#
#
# 4. **Extra Credit:**
#
#   * Implement a hybrid approach (potentially even a dedicated hybrid retriever) that combines results from multiple strategies
#   * Implement a feedback mechanism to improve strategy selection over time
#
#
# ### Decision Criteria for Your Router
# When implementing your router, consider these factors to determine the best strategy:
#
# 1. **Query Structure:**
#
#   * Template patterns: Common patterns with clear entities (template)
#   * Complex relationships: Multi-hop traversals (text2cypher or template) or aggregations (text2cypher)
#   * Semantic/conceptual: Opinion or concept-based queries (vector)
#
#
# 2. **Entity Presence:**
#
#   * Clear entity mentions: Specific hotel names, locations, etc. (template or text2cypher)
#   * Conceptual descriptions: "Luxury", "family-friendly", etc. (vector)
#
#
# 3. **Query Intent:**
#
#   * Fact retrieval: "How many reviews does hotel X have?" (text2cypher)
#   * Opinion extraction: "What do guests say about X?" (vector)
#   * Common lookup patterns: "Tell me about hotel X" (template)

# %% [markdown]
# # Comparing Vector RAG vs Graph RAG: A Practical Analysis
#
# When implementing RAG systems, it's crucial to understand when graph-based approaches offer meaningful advantages over traditional vector RAG. Let's examine some real queries against our hotel reviews knowledge graph to understand these tradeoffs.
#
# ## Case Study 1: Multi-Hop Queries
# ### Query: "What highly-rated hotels near Fisherman's Wharf offer free Wi-Fi and easy access to cable cars?"
#
# #### Vector RAG Response:
# > *Two highly-rated hotels near Fisherman's Wharf that offer free Wi-Fi and easy access to cable cars are
# San Francisco Marriott Fisherman's Wharf and Hotel Riu Plaza Fisherman's Wharf.*
#
# #### Graph RAG Response:
# Using the following Cypher for the retrieval:
# ```cypher
# MATCH (h:HOTEL)-[:LOCATED_NEARBY]->(fw:TOURIST_ATTRACTION {name: 'Fisherman\'s Wharf'}),
#       (h)-[:HAS_AMENITY]->(wifi:AMENITY {name: 'Free Wi-Fi'}),
#       (h)-[:LOCATED_NEARBY]->(cc:TOURIST_ATTRACTION {name: 'San Francisco Cable Car line'}),
#       (h)-[:HAS_REVIEW]->(r:REVIEW)
# WHERE r.rating_value >= 4.0
# RETURN DISTINCT h.name
# ```
#
# >*The Hotel Riu Plaza Fisherman’s Wharf, located in San Francisco, offers free Wi-Fi and easy access to the San Francisco Cable Car line.*
#
# #### Analysis:
# 1. **Accuracy**: Vector RAG incorrectly includes SF Marriott, which doesn't mention free Wi-Fi in its description. Graph RAG correctly identifies only Hotel Riu by following explicit relationships.
#
# 2. **Query Processing**:
#    - Vector RAG attempts to infer relationships from text proximity
#    - Graph RAG follows verified relationship paths
#    - Multi-hop queries strongly favor graph approach
#
# 3. **Confidence**: Graph RAG can guarantee the existence of relationships, while vector RAG makes best guesses
#
# ## Case Study 2: Amenity Comparisons
# ### Query: "Compare amenities and ratings for hotels near Fisherman's Wharf and Pier 39"
#
# Vector RAG Response:
# ```
# Based on the information provided:
#
# 1. **San Francisco Marriott Fisherman's Wharf**:
#    - Amenities: Fitness Center, Handicap Accessible Rooms, Safety Deposit Boxes, Iron, Ironing Board, Hairdryers.
#    - Rating: No specific rating mentioned.
#
# 2. **Hotel Riu Plaza Fisherman’s Wharf**:
#    - Amenities: Free WiFi, Outdoor Pool, Gym, Conference Rooms, Satellite TV, Mini-fridge, Coffee Machine, AC, Buffet Breakfast, Grab & Go Bar.
#    - Rating: No specific rating mentioned.
#
# 3. **Hotel Zephyr San Francisco**:
#    - Amenities: Not specified in the provided information.
#    - Rating: No specific rating mentioned.
#
# 4. **PIER 39**:
#    - Amenities: Shops, Restaurants, Sea lions.
#    - Rating: No specific rating mentioned.
#
# Unfortunately, the information provided does not include specific ratings for the hotels near Fisherman's Wharf and Pier 39, so I cannot provide a direct comparison in terms of ratings. If you have a specific rating range in mind or other criteria for comparison, please let me know.
# ```
#
# Graph RAG Response:
#
# ```
# The Hyatt Centric Fisherman's Wharf San Francisco and Hotel Riu Plaza Fisherman’s Wharf are two hotels near both Fisherman's Wharf and PIER 39.
#
# The Hyatt Centric offers amenities such as Brick & Beam, a Fitness Center, Free Wi-Fi, Meeting Rooms, and a Relaxing Pool. It has an average rating of 4.33.
#
# The Hotel Riu Plaza provides amenities like a Buffet Breakfast Service, a Bar, a Minibar, a TV with Free Movies, and Coffee and Tea Facilities. It has an average rating of 4.0.
# ```
#
# #### Analysis:
# 1. **Structured Data**: Graph RAG excels at comparing discrete attributes
# 2. **Relationship Context**: Understanding nearness to multiple landmarks
# 3. **Aggregation**: Can compute statistics across relationship patterns
#
# ## Key Findings
#
# ### When to Use Graph RAG:
# 1. **Relationship-Critical Queries**
#    - Multiple hops required (e.g., "hotels near X with amenity Y")
#    - Relationship accuracy matters
#    - Complex pattern matching
#
# 2. **Structured Comparisons**
#    - Comparing entities across relationships
#    - Aggregating across relationship patterns
#    - Need for verified connections
#
# 3. **Hybrid Questions**
#    - Combining factual relationships with semantic search
#    - Need both structured and unstructured insights
#
# ### When Traditional Vector RAG Suffices:
# 1. **Simple Semantic Queries**
#    - Single-entity questions
#    - General descriptions or summaries
#    - No relationship traversal needed
#
# 2. **Fuzzy Matching**
#    - When exact relationship matching isn't critical
#    - Flexible interpretation acceptable
#    - General sentiment or topic analysis
#
# ## Implementation Considerations
#
# 1. **Data Quality Requirements**
#    - Graph RAG requires explicit relationship modeling
#    - Higher upfront cost in knowledge graph construction
#    - Need for relationship maintenance/updates
#
# 2. **Query Complexity**
#    - Graph queries can be more complex to construct
#    - Need for query optimization
#    - Hybrid approaches often optimal
#
# 3. **System Architecture**
#    - Graph databases add operational complexity
#    - Vector indices still valuable for semantic search
#    - Consider hybrid architectures for complex applications
